# %%
#有劃線功能 save avi#
import os
video_name = "20230405_123832_4652_A.mp4"
video_path = os.path.join("./output",video_name)
from collections import defaultdict

import cv2
import numpy as np
from ultralytics import YOLO

# 定义全局变量，用于存储鼠标点击的坐标和绘制的线段
points = []
lines = []

# 鼠标点击事件的回调函数
def mouse_callback(event, x, y, flags, param):
    global points, lines
    
    # 如果鼠标左键按下
    if event == cv2.EVENT_LBUTTONDOWN:
        points.append((x, y))
        
        # 当点击了两次后绘制一条线段
        if len(points) == 2:
            lines.append((points[0], points[1]))
            points = []
            
            # 当绘制了四条线段后，退出程序
            if len(lines) == 4:
                cv2.destroyAllWindows()
                
# Load the YOLOv8 model
model = YOLO("best.pt")
# model = YOLO("yolov8n.pt")
# Open the video file

cap = cv2.VideoCapture(video_path)

w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

# Video writer
video_writer = cv2.VideoWriter("./output/OUTPUT.avi", cv2.VideoWriter_fourcc(*"mp4v"), fps, (w, h))

# Store the track history
track_history = defaultdict(lambda: [])

# Loop through the video frames
pause = True  # Flag to pause at the first frame
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        if pause:
            frame_size = frame.shape
            # Display the first frame
            cv2.namedWindow('First Frame with Drawing')
            cv2.setMouseCallback('First Frame with Drawing', mouse_callback)

            # 绘制线段
            while True:
                temp_frame = frame.copy()
                for line in lines:
                    cv2.line(temp_frame, line[0], line[1], (0, 255, 0), 2)
                
                # 在帧上实时显示绘制的线段
                cv2.imshow('First Frame with Drawing', temp_frame)
                
                key = cv2.waitKey(1) & 0xFF
                # 按下ESC键退出循环
                if key == 27 or len(lines) == 4:
                    break
            pause = False
            
        else:
            # Run YOLOv8 tracking on the frame, persisting tracks between frames
            results = model.track(frame, save=True, save_txt=True, persist=True, classes=[0, 1], project="./output/output")
            
            # Get the boxes and track IDs
            boxes = results[0].boxes.xywh.cpu()
            track_ids = results[0].boxes.id.int().cpu().tolist()
        
            # Visualize the results on the frame
            annotated_frame = results[0].plot()

            # Plot the tracks
            for box, track_id in zip(boxes, track_ids):
                x, y, w, h = box
                track = track_history[track_id]
                track.append((float(x), float(y)))  # x, y center point

                # if len(track) > 5:  # retain 90 tracks for 90 frames
                #     track.pop(0)

                # Draw the tracking lines
                points = np.hstack(track).astype(np.int32).reshape((-1, 1, 2))
                cv2.polylines(annotated_frame, [points], isClosed=False, color=(230, 230, 230), thickness=10)

            # Display the annotated frame
            for line in lines:
                cv2.line(annotated_frame, line[0], line[1], (0, 255, 0), 2)
                
                # 在帧上实时显示绘制的线段
                cv2.imshow("YOLOv8 Tracking", annotated_frame)
            
            # Break the loop if 'q' is pressed
            if cv2.waitKey(1) & 0xFF == ord("q"):
                break

            video_writer.write(annotated_frame)
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 5 no lights, 88.2ms
# Speed: 4.0ms preprocess, 88.2ms inference, 1412.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track166
# 1 label saved to output\output\track166\labels
#
# 0: 384x640 5 no lights, 4.0ms
# Speed: 2.0ms preprocess, 4.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track167
# 1 label saved to output\output\track167\labels
#
# 0: 384x640 5 no lights, 4.0ms
# Speed: 1.0ms preprocess, 4.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track168
# 1 label saved to output\output\track168\labels
#
# 0: 384x640 5 no lights, 4.0ms
# Speed: 1.0ms preprocess, 4.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track169
# 1 label saved to output\output\track169\labels
#
# 0: 384x640 5 no lights, 4.0ms
# Speed: 1.0ms preprocess, 4.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track170
# 1 label saved to output\output\track170\labels
#
# 0: 384x640 5 no lights, 4.0ms
# Speed: 1.0ms preprocess, 4.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track171
# 1 label saved to output\output\track171\labels
#
# 0: 384x640 5 no lights, 4.0ms
# Speed: 1.0ms preprocess, 4.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track172
# 1 label saved to output\output\track172\labels
#
# 0: 384x640 5 no lights, 4.0ms
# Speed: 1.0ms preprocess, 4.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track173
# 1 label saved to output\output\track173\labels
#
# 0: 384x640 5 no lights, 4.0ms
# Speed: 1.0ms preprocess, 4.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track174
# 1 label saved to output\output\track174\labels
#
# 0: 384x640 5 no lights, 4.0ms
# Speed: 2.0ms preprocess, 4.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track175
# 1 label saved to output\output\track175\labels
#
# 0: 384x640 5 no lights, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track176
# 1 label saved to output\output\track176\labels
#
# 0: 384x640 5 no lights, 8.2ms
# Speed: 1.0ms preprocess, 8.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track177
# 1 label saved to output\output\track177\labels
#
# 0: 384x640 5 no lights, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track178
# 1 label saved to output\output\track178\labels
#
# 0: 384x640 5 no lights, 4.0ms
# Speed: 2.0ms preprocess, 4.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track179
# 1 label saved to output\output\track179\labels
#
# 0: 384x640 5 no lights, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track180
# 1 label saved to output\output\track180\labels
#
# 0: 384x640 5 no lights, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track181
# 1 label saved to output\output\track181\labels
#
# 0: 384x640 5 no lights, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track182
# 1 label saved to output\output\track182\labels
#
# 0: 384x640 5 no lights, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track183
# 1 label saved to output\output\track183\labels
#
# 0: 384x640 5 no lights, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track184
# 1 label saved to output\output\track184\labels
#
# 0: 384x640 5 no lights, 4.0ms
# Speed: 1.0ms preprocess, 4.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track185
# 1 label saved to output\output\track185\labels
#
# 0: 384x640 5 no lights, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track186
# 1 label saved to output\output\track186\labels
#
# 0: 384x640 5 no lights, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track187
# 1 label saved to output\output\track187\labels
#
# 0: 384x640 5 no lights, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track188
# 1 label saved to output\output\track188\labels
#
# 0: 384x640 4 no lights, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track189
# 1 label saved to output\output\track189\labels
#
# 0: 384x640 3 no lights, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track190
# 1 label saved to output\output\track190\labels
#
# 0: 384x640 3 no lights, 6.0ms
# Speed: 1.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track191
# 1 label saved to output\output\track191\labels
#
# 0: 384x640 3 no lights, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track192
# 1 label saved to output\output\track192\labels
#
# 0: 384x640 3 no lights, 4.0ms
# Speed: 1.0ms preprocess, 4.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track193
# 1 label saved to output\output\track193\labels
#
# 0: 384x640 3 no lights, 4.0ms
# Speed: 1.0ms preprocess, 4.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track194
# 1 label saved to output\output\track194\labels
#
# 0: 384x640 3 no lights, 4.0ms
# Speed: 1.0ms preprocess, 4.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track195
# 1 label saved to output\output\track195\labels
#
# 0: 384x640 3 no lights, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track196
# 1 label saved to output\output\track196\labels
#
# 0: 384x640 3 no lights, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track197
# 1 label saved to output\output\track197\labels
#
# 0: 384x640 3 no lights, 5.5ms
# Speed: 1.0ms preprocess, 5.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track198
# 1 label saved to output\output\track198\labels
#
# 0: 384x640 3 no lights, 4.0ms
# Speed: 1.0ms preprocess, 4.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track199
# 1 label saved to output\output\track199\labels
#
# 0: 384x640 3 no lights, 4.0ms
# Speed: 2.0ms preprocess, 4.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track200
# 1 label saved to output\output\track200\labels
#
# 0: 384x640 4 no lights, 4.0ms
# Speed: 2.0ms preprocess, 4.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track201
# 1 label saved to output\output\track201\labels
#
# 0: 384x640 4 no lights, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track202
# 1 label saved to output\output\track202\labels
#
# 0: 384x640 4 no lights, 4.0ms
# Speed: 1.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track203
# 1 label saved to output\output\track203\labels
#
# 0: 384x640 4 no lights, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track204
# 1 label saved to output\output\track204\labels
#
# 0: 384x640 5 no lights, 4.0ms
# Speed: 1.0ms preprocess, 4.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track205
# 1 label saved to output\output\track205\labels
#
# 0: 384x640 5 no lights, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track206
# 1 label saved to output\output\track206\labels
#
# 0: 384x640 5 no lights, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track207
# 1 label saved to output\output\track207\labels
#
# 0: 384x640 5 no lights, 4.0ms
# Speed: 2.0ms preprocess, 4.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track208
# 1 label saved to output\output\track208\labels
#
# 0: 384x640 5 no lights, 5.5ms
# Speed: 1.0ms preprocess, 5.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track209
# 1 label saved to output\output\track209\labels
#
# 0: 384x640 5 no lights, 4.0ms
# Speed: 1.0ms preprocess, 4.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track210
# 1 label saved to output\output\track210\labels
#
# 0: 384x640 5 no lights, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track211
# 1 label saved to output\output\track211\labels
#
# 0: 384x640 5 no lights, 3.0ms
# Speed: 1.0ms preprocess, 3.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track212
# 1 label saved to output\output\track212\labels
#
# 0: 384x640 5 no lights, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track213
# 1 label saved to output\output\track213\labels
#
# 0: 384x640 5 no lights, 4.0ms
# Speed: 1.0ms preprocess, 4.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track214
# 1 label saved to output\output\track214\labels
#
# 0: 384x640 5 no lights, 4.5ms
# Speed: 1.0ms preprocess, 4.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track215
# 1 label saved to output\output\track215\labels
#
# 0: 384x640 5 no lights, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track216
# 1 label saved to output\output\track216\labels
#
# 0: 384x640 5 no lights, 4.0ms
# Speed: 1.0ms preprocess, 4.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track217
# 1 label saved to output\output\track217\labels
#
# 0: 384x640 5 no lights, 4.0ms
# Speed: 1.0ms preprocess, 4.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track218
# 1 label saved to output\output\track218\labels
#
# 0: 384x640 5 no lights, 4.0ms
# Speed: 1.0ms preprocess, 4.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track219
# 1 label saved to output\output\track219\labels
#
# 0: 384x640 5 no lights, 3.0ms
# Speed: 1.0ms preprocess, 3.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track220
# 1 label saved to output\output\track220\labels
#
# 0: 384x640 5 no lights, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track221
# 1 label saved to output\output\track221\labels
#
# 0: 384x640 5 no lights, 4.0ms
# Speed: 1.0ms preprocess, 4.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track222
# 1 label saved to output\output\track222\labels
#
# 0: 384x640 6 no lights, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track223
# 1 label saved to output\output\track223\labels
#
# 0: 384x640 6 no lights, 7.5ms
# Speed: 1.0ms preprocess, 7.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track224
# 1 label saved to output\output\track224\labels
#
# 0: 384x640 5 no lights, 4.0ms
# Speed: 1.0ms preprocess, 4.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track225
# 1 label saved to output\output\track225\labels
#
# 0: 384x640 5 no lights, 8.5ms
# Speed: 1.0ms preprocess, 8.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track226
# 1 label saved to output\output\track226\labels
#
# 0: 384x640 5 no lights, 6.0ms
# Speed: 1.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track227
# 1 label saved to output\output\track227\labels
#
# 0: 384x640 5 no lights, 4.0ms
# Speed: 1.0ms preprocess, 4.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track228
# 1 label saved to output\output\track228\labels
#
# 0: 384x640 5 no lights, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track229
# 1 label saved to output\output\track229\labels
#
# 0: 384x640 5 no lights, 4.0ms
# Speed: 1.0ms preprocess, 4.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track230
# 1 label saved to output\output\track230\labels
#
# 0: 384x640 5 no lights, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track231
# 1 label saved to output\output\track231\labels
#
# 0: 384x640 5 no lights, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track232
# 1 label saved to output\output\track232\labels
#
# 0: 384x640 5 no lights, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track233
# 1 label saved to output\output\track233\labels
#
# 0: 384x640 5 no lights, 4.0ms
# Speed: 1.0ms preprocess, 4.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track234
# 1 label saved to output\output\track234\labels
#
# 0: 384x640 5 no lights, 6.0ms
# Speed: 1.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track235
# 1 label saved to output\output\track235\labels
#
# 0: 384x640 5 no lights, 4.0ms
# Speed: 1.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track236
# 1 label saved to output\output\track236\labels
#
# 0: 384x640 5 no lights, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track237
# 1 label saved to output\output\track237\labels
#
# 0: 384x640 5 no lights, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track238
# 1 label saved to output\output\track238\labels
#
# 0: 384x640 5 no lights, 6.0ms
# Speed: 1.0ms preprocess, 6.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track239
# 1 label saved to output\output\track239\labels
#
# 0: 384x640 5 no lights, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track240
# 1 label saved to output\output\track240\labels
#
# 0: 384x640 5 no lights, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track241
# 1 label saved to output\output\track241\labels
#
# 0: 384x640 5 no lights, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track242
# 1 label saved to output\output\track242\labels
#
# 0: 384x640 5 no lights, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track243
# 1 label saved to output\output\track243\labels
#
# 0: 384x640 5 no lights, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track244
# 1 label saved to output\output\track244\labels
#
# 0: 384x640 5 no lights, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track245
# 1 label saved to output\output\track245\labels
#
# 0: 384x640 5 no lights, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track246
# 1 label saved to output\output\track246\labels
#
# 0: 384x640 5 no lights, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track247
# 1 label saved to output\output\track247\labels
#
# 0: 384x640 5 no lights, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track248
# 1 label saved to output\output\track248\labels
#
# 0: 384x640 5 no lights, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track249
# 1 label saved to output\output\track249\labels
#
# 0: 384x640 5 no lights, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track250
# 1 label saved to output\output\track250\labels
#
# 0: 384x640 5 no lights, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track251
# 1 label saved to output\output\track251\labels
#
# 0: 384x640 5 no lights, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track252
# 1 label saved to output\output\track252\labels
#
# 0: 384x640 5 no lights, 8.0ms
# Speed: 3.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track253
# 1 label saved to output\output\track253\labels
#
# 0: 384x640 5 no lights, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track254
# 1 label saved to output\output\track254\labels
#
# 0: 384x640 5 no lights, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track255
# 1 label saved to output\output\track255\labels
#
# 0: 384x640 5 no lights, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track256
# 1 label saved to output\output\track256\labels
#
# 0: 384x640 5 no lights, 6.0ms
# Speed: 2.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track257
# 1 label saved to output\output\track257\labels
#
# 0: 384x640 5 no lights, 6.0ms
# Speed: 2.0ms preprocess, 6.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track258
# 1 label saved to output\output\track258\labels
#
# 0: 384x640 5 no lights, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track259
# 1 label saved to output\output\track259\labels
#
# 0: 384x640 5 no lights, 6.0ms
# Speed: 1.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track260
# 1 label saved to output\output\track260\labels
#
# 0: 384x640 5 no lights, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track261
# 1 label saved to output\output\track261\labels
#
# 0: 384x640 5 no lights, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track262
# 1 label saved to output\output\track262\labels
#
# 0: 384x640 5 no lights, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track263
# 1 label saved to output\output\track263\labels
#
# 0: 384x640 5 no lights, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track264
# 1 label saved to output\output\track264\labels
#
# 0: 384x640 5 no lights, 6.0ms
# Speed: 2.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track265
# 1 label saved to output\output\track265\labels
#
# 0: 384x640 5 no lights, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track266
# 1 label saved to output\output\track266\labels
#
# 0: 384x640 6 no lights, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track267
# 1 label saved to output\output\track267\labels
#
# 0: 384x640 6 no lights, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track268
# 1 label saved to output\output\track268\labels
#
# 0: 384x640 5 no lights, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track269
# 1 label saved to output\output\track269\labels
#
# 0: 384x640 5 no lights, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track270
# 1 label saved to output\output\track270\labels
#
# 0: 384x640 5 no lights, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track271
# 1 label saved to output\output\track271\labels
#
# 0: 384x640 5 no lights, 6.0ms
# Speed: 1.0ms preprocess, 6.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track272
# 1 label saved to output\output\track272\labels
#
# 0: 384x640 5 no lights, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track273
# 1 label saved to output\output\track273\labels
#
# 0: 384x640 5 no lights, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track274
# 1 label saved to output\output\track274\labels
#
# 0: 384x640 5 no lights, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track275
# 1 label saved to output\output\track275\labels
#
# 0: 384x640 5 no lights, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track276
# 1 label saved to output\output\track276\labels
#
# 0: 384x640 5 no lights, 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track277
# 1 label saved to output\output\track277\labels
#
# 0: 384x640 5 no lights, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track278
# 1 label saved to output\output\track278\labels
#
# 0: 384x640 5 no lights, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track279
# 1 label saved to output\output\track279\labels
#
# 0: 384x640 5 no lights, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track280
# 1 label saved to output\output\track280\labels
#
# 0: 384x640 4 no lights, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track281
# 1 label saved to output\output\track281\labels
#
# 0: 384x640 4 no lights, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track282
# 1 label saved to output\output\track282\labels
#
# 0: 384x640 4 no lights, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track283
# 1 label saved to output\output\track283\labels
#
# 0: 384x640 4 no lights, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track284
# 1 label saved to output\output\track284\labels
#
# 0: 384x640 4 no lights, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track285
# 1 label saved to output\output\track285\labels
#
# 0: 384x640 4 no lights, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track286
# 1 label saved to output\output\track286\labels
#
# 0: 384x640 4 no lights, 10.5ms
# Speed: 2.0ms preprocess, 10.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track287
# 1 label saved to output\output\track287\labels
#
# 0: 384x640 4 no lights, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track288
# 1 label saved to output\output\track288\labels
#
# 0: 384x640 4 no lights, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track289
# 1 label saved to output\output\track289\labels
#
# 0: 384x640 4 no lights, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track290
# 1 label saved to output\output\track290\labels
#
# 0: 384x640 4 no lights, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track291
# 1 label saved to output\output\track291\labels
#
# 0: 384x640 4 no lights, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track292
# 1 label saved to output\output\track292\labels
#
# 0: 384x640 4 no lights, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track293
# 1 label saved to output\output\track293\labels
#
# 0: 384x640 4 no lights, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track294
# 1 label saved to output\output\track294\labels
#
# 0: 384x640 4 no lights, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track295
# 1 label saved to output\output\track295\labels
#
# 0: 384x640 4 no lights, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track296
# 1 label saved to output\output\track296\labels
#
# 0: 384x640 4 no lights, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track297
# 1 label saved to output\output\track297\labels
#
# 0: 384x640 4 no lights, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track298
# 1 label saved to output\output\track298\labels
#
# 0: 384x640 4 no lights, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track299
# 1 label saved to output\output\track299\labels
#
# 0: 384x640 3 no lights, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track300
# 1 label saved to output\output\track300\labels
#
# 0: 384x640 3 no lights, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track301
# 1 label saved to output\output\track301\labels
#
# 0: 384x640 3 no lights, 15.9ms
# Speed: 2.0ms preprocess, 15.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track302
# 1 label saved to output\output\track302\labels
#
# 0: 384x640 3 no lights, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track303
# 1 label saved to output\output\track303\labels
#
# 0: 384x640 3 no lights, 10.0ms
# Speed: 1.5ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track304
# 1 label saved to output\output\track304\labels
#
# 0: 384x640 3 no lights, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track305
# 1 label saved to output\output\track305\labels
#
# 0: 384x640 3 no lights, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track306
# 1 label saved to output\output\track306\labels
#
# 0: 384x640 3 no lights, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track307
# 1 label saved to output\output\track307\labels
#
# 0: 384x640 3 no lights, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track308
# 1 label saved to output\output\track308\labels
#
# 0: 384x640 3 no lights, 14.9ms
# Speed: 2.0ms preprocess, 14.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track309
# 1 label saved to output\output\track309\labels
#
# 0: 384x640 3 no lights, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track310
# 1 label saved to output\output\track310\labels
#
# 0: 384x640 3 no lights, 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track311
# 1 label saved to output\output\track311\labels
#
# 0: 384x640 3 no lights, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track312
# 1 label saved to output\output\track312\labels
#
# 0: 384x640 3 no lights, 11.0ms
# Speed: 2.5ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track313
# 1 label saved to output\output\track313\labels
#
# 0: 384x640 3 no lights, 17.9ms
# Speed: 3.0ms preprocess, 17.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track314
# 1 label saved to output\output\track314\labels
#
# 0: 384x640 3 no lights, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track315
# 1 label saved to output\output\track315\labels
#
# 0: 384x640 2 no lights, 11.5ms
# Speed: 2.0ms preprocess, 11.5ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track316
# 1 label saved to output\output\track316\labels
#
# 0: 384x640 2 no lights, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track317
# 1 label saved to output\output\track317\labels
#
# 0: 384x640 2 no lights, 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track318
# 1 label saved to output\output\track318\labels
#
# 0: 384x640 2 no lights, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track319
# 1 label saved to output\output\track319\labels
#
# 0: 384x640 2 no lights, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track320
# 1 label saved to output\output\track320\labels
#
# 0: 384x640 2 no lights, 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track321
# 1 label saved to output\output\track321\labels
#
# 0: 384x640 2 no lights, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track322
# 1 label saved to output\output\track322\labels
#
# 0: 384x640 2 no lights, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track323
# 1 label saved to output\output\track323\labels
#
# 0: 384x640 2 no lights, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track324
# 1 label saved to output\output\track324\labels
#
# 0: 384x640 2 no lights, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track325
# 1 label saved to output\output\track325\labels
#
# 0: 384x640 2 no lights, 11.5ms
# Speed: 2.0ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track326
# 1 label saved to output\output\track326\labels
#
# 0: 384x640 2 no lights, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track327
# 1 label saved to output\output\track327\labels
#
# 0: 384x640 2 no lights, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track328
# 1 label saved to output\output\track328\labels
#
# 0: 384x640 2 no lights, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track329
# 1 label saved to output\output\track329\labels
#
# 0: 384x640 2 no lights, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\output\track330
# 1 label saved to output\output\track330\labels

# %%
from shapely.geometry import LineString

road_edges = [LineString(line_data) for line_data in lines]

intersected_keys = []

for key, coords_list in track_history.items():
    car_direction = LineString(coords_list)

    j0 = car_direction.intersects(road_edges[0])
    j1 = car_direction.intersects(road_edges[1])
    j2 = car_direction.intersects(road_edges[2])
    j3 = car_direction.intersects(road_edges[3])

    if (j0 or j2) and (j1 or j3):
        intersected_keys.append(key)

print("Turning Vehicle ID:", intersected_keys)

import os

# 設定基目錄路徑，包含子目錄file0到file9
base_directory = './output'

# 建立一個空的列表來存放包含1的值
values_with_1 = []
unique_values = set()

def check_files_in_directory(directory, delimiter=' '):
    for root, dirs, files in os.walk(directory):
        for filename in files:
            if filename.endswith(".txt"):
                file_path = os.path.join(root, filename)
                # 讀取txt檔案的每一行
                with open(file_path, 'r', encoding='utf-8') as file:
                    for line in file:
                        line = line.strip()
                        # 分割每一行的內容（假設以指定分隔符分隔）
                        columns = line.split(delimiter)
                        # 檢查第一欄是否包含1
                        if columns and '1' in columns[0]:
                            # 將符合條件的值加入到列表中
                            values_with_1.append((file_path, columns[-1]))
                            unique_values.add(columns[-1])
                            break  # 找到符合條件的行後跳出檢查該文件的迴圈

# 首先處理file目錄中的txt檔案及其子目錄中的檔案
file_directory = os.path.join(base_directory, './output/track/labels')
if os.path.exists(file_directory) and os.path.isdir(file_directory):
    check_files_in_directory(file_directory)

# 然後處理file2到file201目錄中的txt檔案
for i in range(2, 166):
    sub_directory = os.path.join(base_directory, f'./output/track{i}/labels')
    # 檢查子目錄是否存在
    if os.path.exists(sub_directory) and os.path.isdir(sub_directory):
        check_files_in_directory(sub_directory)

sorted_unique_values = sorted(unique_values)
int_list = [int(item) for item in sorted_unique_values]
print(f"Turning Light   ID: {int_list}")


for i in range(len(intersected_keys)):
    if intersected_keys[i] in int_list:
        print(f"id{intersected_keys[i]} 有打方向燈")
    else:
        print(f"id{intersected_keys[i]} 沒有打方向燈")
# Out:
# Turning Vehicle ID: [8]
# Turning Light   ID: []
# id8 沒有打方向燈

# %%
import numpy as np
import matplotlib.pyplot as plt

# Find the minimum and maximum x, y values among all line segments
min_x = min_y = float('inf')
max_x = max_y = float('-inf')

for line in track_history.values():
    line_array = np.array(line)
    min_x = min(min_x, np.min(line_array[:, 0]))
    max_x = max(max_x, np.max(line_array[:, 0]))
    min_y = min(min_y, np.min(line_array[:, 1]))
    max_y = max(max_y, np.max(line_array[:, 1]))

# Calculate width and height of line segments
width = max_x - min_x
height = max_y - min_y

# Plot and save each line segment in a separate plot
for key, line in track_history.items():
    plt.figure()
    line_array = np.array(line)
    normalized_x = line_array[:, 0] - min_x
    normalized_y = max_y - line_array[:, 1]  # Invert y-axis
    plt.plot(normalized_x, normalized_y)
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.title(f"Line {key}")
    plt.xlim(0, width)  # Set x-axis limits
    plt.ylim(0, height)  # Set y-axis limits
    plt.savefig(f"line_segment_{key}.png")
    plt.close()
